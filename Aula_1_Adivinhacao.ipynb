# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandamelloz/API-ESTAT-STICASPYTHON/blob/main/Aula_1_Adivinhacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("🎮 Bem-vindo ao Jogo da Adivinhação!")
numero_secreto = random.randint(1, 10)
tentativas = 3

while tentativas > 0:
    print(f"\nVocê tem {tentativas} tentativas.")
    chute = int(input("Adivinhe o número secreto (entre 1 e 10): "))

    if chute == numero_secreto:
        print("🏆 Parabéns, você acertou em cheio!")
        break
    elif chute > numero_secreto:
        print("📉 O número secreto é menor...")
    else:
        print("📈 O número secreto é maior...")

    tentativas -= 1

if tentativas == 0:
    print(f"\n❌ Fim de jogo! O número secreto era {numero_secreto}.")
# Out:
# 🎮 Bem-vindo ao Jogo da Adivinhação!
#
# Você tem 3 tentativas.
# Adivinhe o número secreto (entre 1 e 10): 2
# 📉 O número secreto é menor...
#
# Você tem 2 tentativas.
# Adivinhe o número secreto (entre 1 e 10): 1
# 🏆 Parabéns, você acertou em cheio!
