# %% [markdown]
# <a href="https://colab.research.google.com/github/Vandamelloz/Minicurso-python-colab/blob/main/palavras_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PYTHON
# ALGORITMO
# COMPUTADOR
# JUPYTER
# LOGICA
# PROGRAMACAO
# GIRASSOL
# ASTRONAUTA
# CHOCOLATE
